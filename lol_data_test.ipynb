# %%
from sqlalchemy import create_engine

engine = create_engine("mysql+pymysql://test:"+"test1"+"@14.49.45.15:3306/sumin?charset=utf8",
                        encoding='utf-8')

QUERY = """
    select *
    from basic_data;
"""
df = pd.read_sql(QUERY, engine)
df.tail()
# Out:
#         game_id                                      summoner_id  \
# 995  4502195435  8-RhP9xHeiozXZuIY8JYY42Qb3HcuWfxGIFU7K2BkMsCOSQ
# 996  4502195435  kif6lkSeZf57A-6Ye9awx3KnLvnO4QnRVDo_hg63ffyTOwg
# 997  4502195435  bqTuupnGTDUFYACYji6TtytIdX9Yo-zViuELMh30VZUOAts
# 998  4502195435  Y_0MMNxI6LHOdXj4egUcEWiv2yQm5Gr06AE0E4U9FUOJ7Nw
# 999  4502195435  q74Pmw_Kxj5FTZ47mXH4PKKU8_aNfZyuxswdrm0z5h24nlA
#
#      team_position  game_result  champion  spell_1  spell_2  kill  death  \
# 995            200            0        10       12        4     0      3
# 996            200            0       245       14        4     1      3
# 997            200            0        64       11        4     3      6
# 998            200            0       523        7        4     0      3
# 999            200            0       350       14        3     0      3
#
#      assist  lane   cs  ban_champion
# 995       0     1   55            81
# 996       0     2  126            -1
# ...

# %%
df
# Out:
#         game_id                                       summoner_id  \
# 0    4562950701  KhbgPtAzVMy4RS_J5B4tsPB3qNiiFw1I4NOutKG79dIeon1a
# 1    4562950701    jW77Q1aNEFIyBnUgeRsYRnLXe0oGuRf3JG8AXTFkTBvUhw
# 2    4562950701   FM3238G3cZfdfw1A_VrRhoo6c3qd_VpBGxQaxDS4vUPjsic
# 3    4562950701    4vexJv8ISxAQbRIiSOeVxGNuUKozWBRv0N6sjaUAJ56lrA
# 4    4562950701    pdHOCeN0NtWZyPaBrIaY8UifzT0H0QSN7VBNVB36SNsC1A
# ..          ...                                               ...
# 995  4502195435   8-RhP9xHeiozXZuIY8JYY42Qb3HcuWfxGIFU7K2BkMsCOSQ
# 996  4502195435   kif6lkSeZf57A-6Ye9awx3KnLvnO4QnRVDo_hg63ffyTOwg
# 997  4502195435   bqTuupnGTDUFYACYji6TtytIdX9Yo-zViuELMh30VZUOAts
# 998  4502195435   Y_0MMNxI6LHOdXj4egUcEWiv2yQm5Gr06AE0E4U9FUOJ7Nw
# 999  4502195435   q74Pmw_Kxj5FTZ47mXH4PKKU8_aNfZyuxswdrm0z5h24nlA
#
#      team_position  game_result  champion  spell_1  spell_2  kill  death  \
# 0              100            1        86        4       14     4      4
# ...

# %%
import urllib.request, json 
with urllib.request.urlopen("http://ddragon.leagueoflegends.com/cdn/10.15.1/data/en_US/champion.json") as url:
    champ_data = json.loads(url.read().decode())

# %%
champ_dic
# Out:
# {'266': 'Aatrox',
#  '103': 'Ahri',
#  '84': 'Akali',
#  '12': 'Alistar',
#  '32': 'Amumu',
#  '34': 'Anivia',
#  '1': 'Annie',
#  '523': 'Aphelios',
#  '22': 'Ashe',
#  '136': 'AurelionSol',
#  '268': 'Azir',
#  '432': 'Bard',
#  '53': 'Blitzcrank',
#  '63': 'Brand',
#  '201': 'Braum',
#  '51': 'Caitlyn',
#  '164': 'Camille',
#  '69': 'Cassiopeia',
#  '31': 'Chogath',
#  '42': 'Corki',
#  '122': 'Darius',
#  '131': 'Diana',
#  '119': 'Draven',
#  '36': 'DrMundo',
#  '245': 'Ekko',
#  '60': 'Elise',
#  '28': 'Evelynn',
#  '81': 'Ezreal',
#  '9': 'Fiddlesticks',
#  '114': 'Fiora',
#  '105': 'Fizz',
#  '3': 'Galio',
#  '41': 'Gangplank',
#  '86': 'Garen',
#  '150': 'Gnar',
#  '79': 'Gragas',
#  '104': 'Graves',
#  '120': 'Hecarim',
#  '74': 'Heimerdinger',
#  '420': 'Illaoi',
#  '39': 'Irelia',
#  '427': 'Ivern',
#  '40': 'Janna',
#  '59': 'JarvanIV',
#  '24': 'Jax',
#  '126': 'Jayce',
#  '202': 'Jhin',
#  '222': 'Jinx',
#  '145': 'Kaisa',
#  '429': 'Kalista',
#  '43': 'Karma',
# ...

# %%
ban_top_10 = df.groupby('ban_champion').count()['summoner_id'].sort_values()[::-1].index[:11].tolist()

# %%
[champ_dic[str(i)] for i in ban_top_5[1:]]
# Out:
# ['Nautilus',
#  'Zed',
#  'Yasuo',
#  'LeeSin',
#  'Blitzcrank',
#  'Morgana',
#  'Caitlyn',
#  'Sylas',
#  'Leblanc']

# %%
picl_top_10 = df.groupby('champion').count()['summoner_id'].sort_values()[::-1].index[:11].tolist()

# %%
[champ_dic[str(i)] for i in picl_top_10[1:]]
# Out:
# ['Caitlyn',
#  'LeeSin',
#  'Ashe',
#  'Ekko',
#  'Yasuo',
#  'Malphite',
#  'Zed',
#  'Graves',
#  'Yuumi',
#  'Varus']
